# %%
# import modules
import pandas as pd
import tweepy

# %%
 
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
        print()
        print(f"Tweet {n}:")
        print(f"Username:{ith_tweet[0]}")
        print(f"Description:{ith_tweet[1]}")
        print(f"Location:{ith_tweet[2]}")
        print(f"Following Count:{ith_tweet[3]}")
        print(f"Follower Count:{ith_tweet[4]}")
        print(f"Total Tweets:{ith_tweet[5]}")
        print(f"Retweet Count:{ith_tweet[6]}")
        print(f"Tweet Text:{ith_tweet[7]}")
        print(f"Hashtags Used:{ith_tweet[8]}")
 
 
# function to perform data extraction
def scrape(words, date_since, numtweet):
 
        # Creating DataFrame using pandas
        db = pd.DataFrame(columns=['username',
                                   'description',
                                   'location',
                                   'following',
                                   'followers',
                                   'totaltweets',
                                   'retweetcount',
                                   'text',
                                   'hashtags'])
 
        # We are using .Cursor() to search
        # through twitter for the required tweets.
        # The number of tweets can be
        # restricted using .items(number of tweets)
        tweets = tweepy.Cursor(api.search_tweets,
                               words, lang="en",
                               since_id=date_since,
                               tweet_mode='extended').items(numtweet)
 
 
        # .Cursor() returns an iterable object. Each item in
        # the iterator has various attributes
        # that you can access to
        # get information about each tweet
        list_tweets = [tweet for tweet in tweets]
 
        # Counter to maintain Tweet Count
        i = 1
 
        # we will iterate over each tweet in the
        # list for extracting information about each tweet
        for tweet in list_tweets:
                username = tweet.user.screen_name
                description = tweet.user.description
                location = tweet.user.location
                following = tweet.user.friends_count
                followers = tweet.user.followers_count
                totaltweets = tweet.user.statuses_count
                retweetcount = tweet.retweet_count
                hashtags = tweet.entities['hashtags']
 
                # Retweets can be distinguished by
                # a retweeted_status attribute,
                # in case it is an invalid reference,
                # except block will be executed
                try:
                        text = tweet.retweeted_status.full_text
                except AttributeError:
                        text = tweet.full_text
                hashtext = list()
                for j in range(0, len(hashtags)):
                        hashtext.append(hashtags[j]['text'])
 
                # Here we are appending all the
                # extracted information in the DataFrame
                ith_tweet = [username, description,
                             location, following,
                             followers, totaltweets,
                             retweetcount, text, hashtext]
                db.loc[len(db)] = ith_tweet
 
                # Function call to print tweet data on screen
                printtweetdata(i, ith_tweet)
                i = i+1
        filename = 'scraped_tweets.csv'
 
        # we will save our database as a CSV file.
        db.to_csv(filename)

# %%
if __name__ == '__main__':
 
        # Enter your own credentials obtained
        # from your developer account
        consumer_key = "AKJRvPwuZS686p1dxkTx3WDnV"
        consumer_secret = "MZ2dakCiJtGBzBkpfTVMFHIlPlwJjYV1bOZg5RN0qIRKxi8d6i"
        access_key = "1498368813867413505-CosP8pC5BUHY9W730ZbjcNhaA9Gk0m"
        access_secret = "eBAL5p7c4DYZVGsIPpRYHQObsAt1HEBsomcGYjUEAwT47"
 
 
        auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_key, access_secret)
        api = tweepy.API(auth,wait_on_rate_limit = True)

# %%
# Enter Hashtag and initial date
print("Enter Twitter HashTag to search for")
words = input()
print("Enter Date since The Tweets are required in yyyy-mm--dd")
date_since = input()
# number of tweets you want to extract in one run
numtweet = 1000
scrape(words, date_since, numtweet)
print('Scraping has completed!')
# Out:
# Enter Twitter HashTag to search for
# #Ukraine
# Enter Date since The Tweets are required in yyyy-mm--dd
# 2022-02-10
# Rate limit reached. Sleeping for: 290
# Tweet 1:
# Username:Mike_Fabricant
# Description:Socially liberal MP for #Lichfield. Believes in an independent, Global Britain. Loves hill walking, travel, red wine, cosy restaurants & pubs, and people.
# Location:Lichfield in Staffordshire, UK
# Following Count:1232
# Follower Count:51348
# Total Tweets:69164
# Retweet Count:0
# Tweet Text:from the Foreign Minister of #Ukraine 🇺🇦👇 https://t.co/RWwnZd3So8
# Hashtags Used:['Ukraine']
#
# Tweet 2:
# Username:Fidget02
# Description:Digital forensics & aviation expert. Previously one of the top 57 pioneering female leaders in UK. https://t.co/PngHiJtvG4
# Location:UK
# Following Count:2947
# Follower Count:2732
# Total Tweets:54359
# Retweet Count:0
# Tweet Text:02/05/2022 #StandWithUkraine #Ukraine #DigitalResistance ** Verified** #Donetsk #Luhansk https://t.co/BuvR0OTuQm
# Hashtags Used:['StandWithUkraine', 'Ukraine', 'DigitalResistance', 'Donetsk', 'Luhansk']
#
# Tweet 3:
# Username:WilliamMcTweets
# Description:a work in progress, attorney, veteran, privacy + security, still searching for the world’s tastiest taco.
# Location:Massachusetts, USA
# Following Count:1212
# Follower Count:151
# Total Tweets:5362
# Retweet Count:402
# Tweet Text:NEW: Pentagon says #Ukraine forces pushed #Russia 40km East of Kharkiv
#
# • ‘Incredible effort’ in last 48 hrs
# • Pushed to Donbas region
# • Russia progress ‘anemic’
# • Ru Generals been killed but US doesn’t have exact number
# • 80% of Howitzers delivered https://t.co/gwx7lrqksj
# Hashtags Used:['Ukraine', 'Russia']
#
# Tweet 4:
# Username:wodenblake
# Description:Herrscher of Chaos 🇬🇧🇩🇪
# Location:Laniakea Supercluster
# Following Count:51
# Follower Count:23
# Total Tweets:4170
# Retweet Count:539
# Tweet Text:#American howitzers will arrive in #Ukraine very soon to effectively destroy the occupiers. https://t.co/ZcWqlSbkGK
# Hashtags Used:['American', 'Ukraine']
#
# Tweet 5:
# Username:MichelPir2
# Description:veux toujours le bonheur de mes enfants et fais la maxi pour !
# Location:
# Following Count:940
# Follower Count:100
# Total Tweets:18268
# Retweet Count:61
# Tweet Text:Goodnight #Ukraine. Just a reminder. https://t.co/LjhaGzSSTk
# Hashtags Used:['Ukraine']
#
# Tweet 6:
# Username:Romanovichphoto
# Description:Sports and Nature Photographer
# Location:
# Following Count:453
# Follower Count:117
# Total Tweets:3175
# Retweet Count:0
# Tweet Text:Even as he tries to turn the corner, #OlafScholz can't stop #Germansplaining #Ukraine.  As I recall, real allies stood with #Zelenski that day.  There was no reason to include #putinpuppet #Steinmeier, who was still throwing sand in the gears. Sorry if his vanity was offended. https://t.co/dlXEmSPV1V https://t.co/aNfJdAGyT3
# Hashtags Used:['OlafScholz', 'Germansplaining', 'Ukraine', 'Zelenski', 'putinpuppet', 'Steinmeier']
#
# Tweet 7:
# Username:Pepesplants
# Description:America does not have a racist problem! It has a marxist problem!!
# go here: https://t.co/ZUJfNWqfgX
#  RT = it's interesting, not endorsement.
# Location:United States
# Following Count:11688
# Follower Count:11010
# Total Tweets:74100
# Retweet Count:0
# Tweet Text:Is this #Disinformation #Russia #Ukraine #Putin #FJB #Hunter #LaptopFromHell #Maga #Trump #Truth #Opinion #FBI #CIA #WEF #KlausSchwab #GreatReset https://t.co/6QBWmQ8bW2
# Hashtags Used:['Disinformation', 'Russia', 'Ukraine', 'Putin', 'FJB', 'Hunter', 'LaptopFromHell', 'Maga', 'Trump', 'Truth', 'Opinion', 'FBI', 'CIA', 'WEF', 'KlausSchwab', 'GreatReset']
#
# Tweet 8:
# Username:ErinBowers1123
# Description:❤️family, Christian, Trump, MAGA, America 🇺🇸First, Support Israel 🇮🇱hockey fan, Followed by Charles Payne,Jim Jordan,Stephanie Hamill, Michael Johns
# Location:
# Following Count:4463
# Follower Count:4485
# Total Tweets:22238
# Retweet Count:19
# Tweet Text:In an interview with current "Jewish" president of Ukraine #Zelensky, he calls Stephan Bandera an undeniable hero of #Ukraine. 🤮🤢
#
# #Bandera is a Ukrainian responsible for the death of some 100,000 #Poles.
#
# #Poland #Putin #Hitler #Azov #Russia #Germany https://t.co/qXAWkr3Gec
# Hashtags Used:['Zelensky']
#
# Tweet 9:
# Username:josefluna
# Description:Venezolano
# Location:Lara, Venezuela
# Following Count:677
# Follower Count:399
# Total Tweets:5928
# Retweet Count:459
# Tweet Text:#Ukraine: An interesting improvised weapon was spotted in the hands of Ukrainian troops - a MT-LBu APC modded with two B-8M1 jet rocket pods - each pod is loaded with 20 S-8 80mm aircraft rockets. Such a system is basically a makeshift MLRS with shorter range and worse accuracy. https://t.co/bonS4LY1oH
# Hashtags Used:['Ukraine']
#
# Tweet 10:
# Username:DanKoosh
# Description:Chief Cinematographer | Producer & Director | CEO at Dan Koosh Studios & https://t.co/pJHVyUXRyT | Developing Exclusive Private #Vineyard #Resort in #PasoRobles, #Calif
# Location:Los Angeles
# Following Count:3092
# Follower Count:13916
# Total Tweets:13579
# Retweet Count:1
# Tweet Text:@KremlinRussia_E The classic loser, The typical moron of #Russia [#Putin] has no balls to even come close in attacking #US or #UK!! He knows he will be wiped of the earth! -- Attacking #Ukraine is NO SHOW OF POWER, but the opposite. THE SHOW OF WEAKNESS!!!
# Hashtags Used:['Russia', 'Putin', 'US']
#
# Tweet 11:
# Username:wiccanwarlock
# Description:STOP KILLING UKRAINIAN KIDS! HAVE SOME RESPECT FOR YOURSELVES!
# Location:London
# Following Count:389
# Follower Count:480
# Total Tweets:12223
# Retweet Count:2
# Tweet Text:#Ukraine &amp; Israel condemn #Russian Foreign Minister Lavrov after he claimed Hitler had “Jewish blood."
#
# "They are once again undermining any lasting sense of possible neutrality in #Israel," says @b_judah Senior Fellow @AtlanticCouncil.
#
# cc @ZainAsher https://t.co/xBJgbSA4z6
# Hashtags Used:['Ukraine', 'Russian']
#
# Tweet 12:
# Username:P4BlPArWhxXnsyY
# Description:善悪(宗教)でもなく正誤(科学)でもなく
# 優先順位(政治)が大事
# なーんて出来たらいいな。
# ユルユルな頭でゴメンネ
# ❤️は良いねもあるし確認の意味だったりも…
# リツイートはみんなはどう？です
# 二つ合わさると…☺️
# Location:
# Following Count:470
# Follower Count:688
# Total Tweets:99612
# Retweet Count:514
# Tweet Text:May 2, 2022 is the 8th anniversary of the #OdessaMassacre where a mob of #Ukraine ultra nationalists burnt 48 people alive in the Trade Union building. UN monitor Matilda Bogner said in 2021 that trials for the murders had not progressed because of a lack of "political will". https://t.co/lubqgpWCaf
# Hashtags Used:['OdessaMassacre', 'Ukraine']
#
# Tweet 13:
# Username:Emmie12750
# Description:I'm really just here to follow my favorite shows and celebrities and be a nosy person :-) Criminal Minds, news, food, and random silliness. Alt: @emmie12750x2
# Location:Massachusetts
# Following Count:3561
# Follower Count:2129
# Total Tweets:204245
# Retweet Count:8
# Tweet Text:After a bombardment a cat got trapped in a destroyed building. These #Ukrainian heroes brought a crane and rescued the cat 🐈. #StandWithUkraine #CatsofTwittter #ukraine https://t.co/uQMkXF3T2V
# Hashtags Used:['Ukrainian']
#
# Tweet 14:
# Username:pacos_gal
# Description:
# Location:
# Following Count:1643
# Follower Count:313
# Total Tweets:112994
# Retweet Count:3
# Tweet Text:Strikes on Odesa and destroyed russian boats: Odesa, recap of 2 May. Full-scale Russian invasion of Ukraine
#
# #Odesa #StopRussia #StandWithUkraine #armUkraineNow #Ukraine #UkraineRussiaWar #2may #2мая #2травня https://t.co/gOwafP8ufq
# Hashtags Used:['Odesa']
#
# Tweet 15:
# Username:Sinh_MD
# Description:citizenship with knowledge and passion
# Location:
# Following Count:361
# Follower Count:868
# Total Tweets:1394
# Retweet Count:0
# Tweet Text:#munichsecurityconference #Zelensky #MSC2022 Budapest Promise. #NATO #england #USA 1938 #putin #biden #ukraine #russia https://t.co/GzDMzLLXid
# Hashtags Used:['munichsecurityconference', 'Zelensky', 'MSC2022', 'NATO', 'england', 'USA', 'putin', 'biden', 'ukraine', 'russia']
#
# Tweet 16:
# Username:MR_ANONWOLF
# Description:#CEH,#Investigator...etc
# #WeAreLegion👥👤#DoNotForgive🏴‍☠ #DoNotForget📣#ExpectUs 🏴#Anonymous🌐
# #OpKilluminati ▽
# #CloversForAssange🍀
# #HackThePlanet🌎🌍🌏
# Location:.close
# Following Count:1481
# Follower Count:1342
# Total Tweets:10532
# Retweet Count:49
# Tweet Text:JUST IN: The amazing @squad3o3 continues to provide a way to send messages to Russian about the war in #Ukraine to fight Russian propaganda. Over 100 million messages sent so far from warriors all over the world. #OpRussia #Anonymous https://t.co/4xFYx4sfHS https://t.co/GyjPgjkEgU
# Hashtags Used:['Ukraine']
#
# Tweet 17:
# Username:stefandemarco13
# Description:Vagabondo | Free Thinker | #Bitcoin
# Location:
# Following Count:451
# Follower Count:35
# Total Tweets:963
# Retweet Count:1199
# Tweet Text:My thoughts on some potential #Neocon objectives. #Zelenskyy #Putin #Ukraine #Donbass #Russia #VictoriaNuland https://t.co/rC0EZbNO06
# Hashtags Used:['Neocon', 'Zelenskyy', 'Putin', 'Ukraine', 'Donbass', 'Russia', 'VictoriaNuland']
#
# Tweet 18:
# Username:TgrayAlemey
# Description:#stopTigrayGonocide
# Location:
# Following Count:350
# Follower Count:209
# Total Tweets:11590
# Retweet Count:57
# Tweet Text:#humanitycomesfirst As the world focuses on #Ukraine, we urge #AusGov &amp; UN members to not forget Tigray, a region cut off from the world. Very little aid has entered the region, #AusGov can do more! #TigrayCantWait #AusPol #AusGovActNow @MarisePayne @dfat @scottmorrisonMP
# Hashtags Used:['humanitycomesfirst', 'Ukraine', 'AusGov']
#
# Tweet 19:
# Username:TonyFradelich
# Description:
# Location:
# Following Count:0
# Follower Count:177
# Total Tweets:23
# Retweet Count:1199
# Tweet Text:My thoughts on some potential #Neocon objectives. #Zelenskyy #Putin #Ukraine #Donbass #Russia #VictoriaNuland https://t.co/rC0EZbNO06
# Hashtags Used:['Neocon', 'Zelenskyy', 'Putin', 'Ukraine', 'Donbass', 'Russia', 'VictoriaNuland']
#
# Tweet 20:
# Username:karenbway_karen
# Description:Retweets/tweets political stuff and dog pictures also an EU citizen oh and trolls Bogus Johnson because he’s a useless fat liar
# Location:South West, England
# Following Count:4476
# Follower Count:4079
# Total Tweets:142155
# Retweet Count:12
# Tweet Text:Against all of his wishes, #BorisJohnson will forever be remembered for #Partygate. #Brexit yes, #Ukraine maybe, #covid possibly, but mainly the first #PM to break the law over and over again through partygate.
#
# Make you proud?
#
# MAKE SURE YOU #VOTE
# Hashtags Used:['BorisJohnson', 'Partygate', 'Brexit', 'Ukraine']
#
# Tweet 21:
# Username:Chritchen
# Description:INTP (https://t.co/44F9q2z4Qo). E. types: 9, 4, 2. Aquarius, Libra. Ravenclaw. He/him. 'Rwandan'. Albus, Dale and Willow (https://t.co/W1MOkrSd0j)
# Location:Italy
# Following Count:5001
# Follower Count:1557
# Total Tweets:44018
# Retweet Count:2
# Tweet Text:Meet Hurrem Sultan, also known as Roksolana, born in #Ukraine in the beginning of the XVI century. She was the wife of Ottoman Emperor Suleiman the Magnificent. She became the first woman in the history of the East who shared the right of rule with her husband. #MetGala2022 https://t.co/WUOCTj171Y https://t.co/RWObhL84ho
# Hashtags Used:['Ukraine']
#
# Tweet 22:
# Username:Captain12201940
# Description:Operation Mockingbird is a large-scale program of the CIA that began in 1948 & attempts to manipulate news media for propaganda purposes.
# Location:
# Following Count:208
# Follower Count:55
# Total Tweets:463
# Retweet Count:2
# Tweet Text:Anti- Imperialist U: Nazis and the #CIA https://t.co/rC63y81Gtt #History #ColdWar #Spain #Germany #Italy #Ukraine https://t.co/vjewzJIZNa
# Hashtags Used:['CIA', 'History', 'ColdWar', 'Spain', 'Germany', 'Italy', 'Ukraine']
#
# Tweet 23:
# Username:KateAus1976
# Description:Born in Leeds but live in the US $LIB1972
# Location:
# Following Count:1509
# Follower Count:1012
# Total Tweets:161514
# Retweet Count:226
# Tweet Text:#Ukraine Eyewitnesses reported a massive fire in the Azovstal area in Mariupol. The video shows large clouds of smoke. https://t.co/p51Aeb63hv
# Hashtags Used:['Ukraine']
#
# Tweet 24:
# Username:dekentro
# Description:I can tell you the future
# Location:Antarctica
# Following Count:1076
# Follower Count:338
# Total Tweets:83616
# Retweet Count:57
# Tweet Text:Good night, and Glory to #Ukraine 🇺🇦✊🏻 https://t.co/q6GyABwkwr
# Hashtags Used:['Ukraine']
#
# Tweet 25:
# Username:AaerGplay
# Description:
# Location:
# Following Count:165
# Follower Count:20
# Total Tweets:1262
# Retweet Count:556
# Tweet Text:#Russia in #Ukraine in a nutshell.
#
# Same goes for its merry band of Twitter trolls.
#
# Glory to #Ukraine ✊🏻🇺🇦 https://t.co/u7t2rJM3kQ
# Hashtags Used:['Russia', 'Ukraine', 'Ukraine']
#
# Tweet 26:
# Username:banmk
# Description:Graduate of International Politics & 3rd World with a focus in MENA Region. These are my own personal views.
# Location:
# Following Count:331
# Follower Count:261
# Total Tweets:1081
# Retweet Count:0
# Tweet Text:Published in 2014. Are Putin's actions viewed as some of his ambitions to become the new Tsar of #Europe ? #Ukraine #Russia https://t.co/EJZhB9CwIm
# Hashtags Used:['Europe', 'Ukraine', 'Russia']
#
# Tweet 27:
# Username:conspraicyy
# Description:The deepest “conspiracy” page on Twitter. Conspiracyy.o on all socials:)
# Location:
# Following Count:14
# Follower Count:2
# Total Tweets:60
# Retweet Count:0
# Tweet Text:#NATO influencing the east, and by sending weapons to Ukraine, that puts us at the brink of nuclear war. Putin stated in an interview today that London, Berlin, and another European state could be bombed in 200 seconds, leaving no survivors. Are his comments justified? #Ukraine https://t.co/Scgbx5fwCo
# Hashtags Used:['NATO', 'Ukraine']
#
# Tweet 28:
# Username:rsraob
# Description:
# Location:
# Following Count:15
# Follower Count:2
# Total Tweets:54
# Retweet Count:0
# Tweet Text:#endveto @UN @DrSJaishankar #Ukraine disaster happened because Russia has VETO. If UN had put faith I majority not the few. This disaster could have been easily be avoided.
# Hashtags Used:['endveto', 'Ukraine']
#
# Tweet 29:
# Username:Marcella1717
# Description:Our lives begin to end the day we become silent about things that matter - Martin Luther King jr 🙂 Also on Gab
# Location:Lost in Europe
# Following Count:3655
# Follower Count:1519
# Total Tweets:28775
# Retweet Count:49
# Tweet Text:Sorry for no updates today. I spent what little time I had translating this poem by Vadim #Negaturov, who was burned alive by #Ukraine|ian fascists, along with over 200 other victims, in the #Odessa #Khatyn Massacre of May 2, 2014. I felt it was more important to pay this homage. https://t.co/3nMwvKsnqY
# Hashtags Used:['Negaturov']
#
# Tweet 30:
# Username:Barbiewithatude
# Description:Pulling random flotsam and jetsam out of the sieve that is my brain. Natural blonde - never met a joke I couldn't walk straight into without seeing it coming.
# Location:San Diego
# Following Count:4994
# Follower Count:2926
# Total Tweets:592962
# Retweet Count:79
# Tweet Text:#Ukraine's Security Service has identified 900 Russian military who committed crimes against civilians in Kyiv region &amp; they're checking over 2,500 🇷🇺 soldiers whose units were in the Kyiv region. So far they've interviewed 7,000 witnesses to 🇷🇺 atrocities https://t.co/Ly8pztJmZf
# Hashtags Used:['Ukraine']
#
# Tweet 31:
# Username:nonoford97
# Description:Living my best life 🤟😤😎🥺💪
# Location:
# Following Count:35
# Follower Count:26
# Total Tweets:3899
# Retweet Count:396
# Tweet Text:#Ukraine: Some more footage made its way to us from Snake Island- another Ukrainian Bayraktar TB-2 drone strike.
#
# This time a Russian 9K35 Strela-10(M) short range SAM system was struck- we have slowed the video down so you can observe a missile streaking off after being hit. https://t.co/nH72jm7kry
# Hashtags Used:['Ukraine']
#
# Tweet 32:
# Username:whereisrosiee
# Description:
# Location:
# Following Count:455
# Follower Count:96
# Total Tweets:54415
# Retweet Count:35
# Tweet Text:The Strong Link Between Authoritarianism and the Climate Crisis
# Main Topic on the Extreme Temperature Diary- MON May 2nd 2022
# Post: https://t.co/KinxnvII7z
# +new #ClimateCrisis #Weather &amp; #Ukraine articles
# @MichaelEMann @ThomasSBateman
# @edgarrmcgregor @KHayhoe @AlexandriaV2005 https://t.co/nk9JM6AhL1
# Hashtags Used:[]
#
# Tweet 33:
# Username:beast_behind
# Description:Retwitter, collect data: RuSSia, Ukraine, Sirya & little bit of computer science. In a fierce fight with RuSSian prop in Bulgaria.
# Location:Bulgaria
# Following Count:2297
# Follower Count:303
# Total Tweets:65825
# Retweet Count:396
# Tweet Text:#Ukraine: Some more footage made its way to us from Snake Island- another Ukrainian Bayraktar TB-2 drone strike.
#
# This time a Russian 9K35 Strela-10(M) short range SAM system was struck- we have slowed the video down so you can observe a missile streaking off after being hit. https://t.co/nH72jm7kry
# Hashtags Used:['Ukraine']
#
# Tweet 34:
# Username:jvoc_Kemptown
# Description:St James’s St resident, Brighton. LGBT. she/her.  Retired RAF officer and senior Systems Engineer. Graduate Sussex University.
# Location:Brighton UK
# Following Count:257
# Follower Count:156
# Total Tweets:6056
# Retweet Count:396
# Tweet Text:#Ukraine: Some more footage made its way to us from Snake Island- another Ukrainian Bayraktar TB-2 drone strike.
#
# This time a Russian 9K35 Strela-10(M) short range SAM system was struck- we have slowed the video down so you can observe a missile streaking off after being hit. https://t.co/nH72jm7kry
# Hashtags Used:['Ukraine']
#
# Tweet 35:
# Username:BashirS72770124
# Description:I hate imperialism and imperialist, and I also hate hegemony and those behind it.
# Location:
# Following Count:2536
# Follower Count:31
# Total Tweets:5461
# Retweet Count:50
# Tweet Text:#Russia #Ukraine 🇷🇺🇺🇦: #Russian AF have seized anti-tank weapons from #Ukrainian AF in #Izyum, #Kharkiv:
#
# —#NLAW ATGMs 🇬🇧
# —2022-dated RPG-75-M 🇨🇿
# —FGM-148 #Javelin ATGMs 🇺🇸
# —Panzerfaust 3-IT with DM72A1 projectiles 🇩🇪
# —RK-2S Tandem-charge HEAT missile for Stugna-P/Skif systems 🇺🇦 https://t.co/zlR4Gt3ZZw
# Hashtags Used:['Russia', 'Ukraine', 'Russian', 'Ukrainian', 'Izyum', 'Kharkiv', 'NLAW']
#
# Tweet 36:
# Username:Lord_God_save
# Description:🩸 Russland Geschäfte machen, fördern den Terrorismus (Das ist gegen GOTT) Doing business with Russia promotes terrorism (This is against GOD) БОГ спаси Украину
# Location:Украина
# Following Count:2
# Follower Count:0
# Total Tweets:269
# Retweet Count:0
# Tweet Text:#Musk #Europe #Ukrane  #Ukrainian #Lithuania #Turkey #France #Ukrainewar #Moldova #Russian putin's war crimes #UkraineWarCrimes putin's war crimes
# #Ukraine #Russia #Romania #Poland  #russiaukrainewar #russia #Ukraine #estonia #latvia
#
# putin's war crimes
# https://t.co/TcnwLHV3Mr https://t.co/6dmA1qVbNC
# Hashtags Used:['Musk', 'Europe', 'Ukrane', 'Ukrainian', 'Lithuania', 'Turkey', 'France', 'Ukrainewar', 'Moldova', 'Russian', 'UkraineWarCrimes', 'Ukraine', 'Russia', 'Romania', 'Poland', 'russiaukrainewar', 'russia', 'Ukraine', 'estonia', 'latvia']
#
# Tweet 37:
# Username:jd_kelleher
# Description:Irish tenor. Gender Questioning. He/Him/They 🏳️‍🌈 Check the videography https://t.co/gtXnLPrW4g…
# Location:London
# Following Count:689
# Follower Count:939
# Total Tweets:19813
# Retweet Count:0
# Tweet Text:The equivalent of the entire population of Ireland has now fled #Ukraine.
# Oh and can someone please let the Russian state media know that Ireland isn't a British Isle. Kinda urgent.
# https://t.co/JRsyi3omwf
# Hashtags Used:['Ukraine']
#
# Tweet 38:
# Username:Hansonian88
# Description:Sic Semper Tyrannis
# Location:
# Following Count:1723
# Follower Count:536
# Total Tweets:6451
# Retweet Count:3323
# Tweet Text:"I want to say one thing: @elonmusk's Starlink is what changed the war in #Ukraine's favour. #Russia went out of its way to blow up all our comms. Now they can't. Starlink works under Katyusha fire, under artillery fire. It even works in Mariupol." https://t.co/C2QnVTE3tc
# Hashtags Used:['Ukraine', 'Russia']
#
# Tweet 39:
# Username:clearvluesky
# Description:Animal lover and proud RESISTER!! BIDEN 2020
# Location:Charleston, SC
# Following Count:834
# Follower Count:304
# Total Tweets:23420
# Retweet Count:831
# Tweet Text:This man has been working every single day of war. Every time we felt scared, depressed, disappointed, upset - he would just get up and open his booth and sell fruit and veggies.
# I bow to all people of #Ukraine who never stopped working. Never stopped building and moving forward. https://t.co/EKZ46SA0WU
# Hashtags Used:[]
#
# Tweet 40:
# Username:donnapivarnik1
# Description:
# Location:
# Following Count:1276
# Follower Count:320
# Total Tweets:18982
# Retweet Count:831
# Tweet Text:This man has been working every single day of war. Every time we felt scared, depressed, disappointed, upset - he would just get up and open his booth and sell fruit and veggies.
# I bow to all people of #Ukraine who never stopped working. Never stopped building and moving forward. https://t.co/EKZ46SA0WU
# Hashtags Used:[]
#
# Tweet 41:
# Username:Cubanitoray2005
# Description:#Jewban BIDEN BEAT’S TRUMP 2020”#Soldier #NationalGuard WE ARE NOT MEARLY PROTESTERS WEARE THE #RESISTANCE @HILLARYCLINTON IS QUEEN #Trumpisnotmypresident
# Location:Miami Beach SoBe La Playa
# Following Count:4861
# Follower Count:3600
# Total Tweets:90711
# Retweet Count:1732
# Tweet Text:#Azovstal ✊🏻🇺🇦
#
# Glory to #Ukraine, glory to Heroes! https://t.co/DkuFoao4yt
# Hashtags Used:['Azovstal', 'Ukraine']
#
# Tweet 42:
# Username:KristoferRaven1
# Description:Homme. De gauche pour certains points, de droite pour d'autres, mais avant tout pro science, anti complotistes, anti fakemeds... Fan de SF
# Location:Valhalla
# Following Count:127
# Follower Count:24
# Total Tweets:1887
# Retweet Count:102
# Tweet Text:30 avril 2022, #Paris 🇺🇦🇫🇷#StandWithUkraine #Ukraine #SlavaUkraini ✊🌻From France To #Marioupol #Mykolaiv #Kherson #Kharkiv #Irpin #Odessa #Kyiv #Bucha #Borodyanka #Kramartosk #Lviv with Love💙💛                 @afpfr @Reuters @AP @libe @lemondefr @BFMTV @LCI @lobs @le_Parisien https://t.co/EgcyZx0qtJ
# Hashtags Used:['Paris', 'StandWithUkraine', 'Ukraine', 'SlavaUkraini', 'Marioupol', 'Mykolaiv', 'Kherson']
#
# Tweet 43:
# Username:yassunjohnson
# Description:ディープなバランス感覚原理主義者。 Instagram ☞yassunjohnson JPN🇯🇵ーNZ🇳🇿ーDenver🇺🇸ーOrange County🇺🇸ーJPN🇯🇵
# Location:
# Following Count:236
# Follower Count:535
# Total Tweets:251048
# Retweet Count:801
# Tweet Text:Invaders destroy the historical heritage of Ukraine
#
# The #Russians destroyed the building of the 19th century #Lisichansk gymnasium, which was built by Belgian masters.
#
# It was one of the most beautiful schools in #Ukraine. https://t.co/0NrzBajUzN
# Hashtags Used:['Russians', 'Lisichansk']
#
# Tweet 44:
# Username:MarshaBrett1
# Description:Political Junkie #STRONGERINUMBERS DEMOCRAT HANDMARKEDPAPERBALLOTS NFLNBAMLB MYTWITTERACCOUNTWASHACKEDStartingOverUGH
# Location:United States
# Following Count:1080
# Follower Count:112
# Total Tweets:4893
# Retweet Count:292
# Tweet Text:You want to see some extreme shit?
#
# #Ukrainian troops in a civilian vehicle chased by a #Russian BTR.
#
# Glory to #Ukraine 🇺🇦✊🏻 https://t.co/4GLxD2aMIQ
# Hashtags Used:['Ukrainian', 'Russian']
#
# Tweet 45:
# Username:VickieSneddon
# Description:Animal advocate and political junkie. An Ohio girl through & through.
# Location:Perth, Western Australia
# Following Count:1196
# Follower Count:418
# Total Tweets:20947
# Retweet Count:49
# Tweet Text:JUST IN: The amazing @squad3o3 continues to provide a way to send messages to Russian about the war in #Ukraine to fight Russian propaganda. Over 100 million messages sent so far from warriors all over the world. #OpRussia #Anonymous https://t.co/4xFYx4sfHS https://t.co/GyjPgjkEgU
# Hashtags Used:['Ukraine']
#
# Tweet 46:
# Username:AnonSquad035
# Description:We are Anonymous
# We do not Forgive
# We do not Forget
# Expect us!
# Active DIAit&PedoHunter. Rep. Abuse: https://t.co/JiUNfJB3Vg
# Location:Everywhere
# Following Count:1851
# Follower Count:1772
# Total Tweets:8635
# Retweet Count:0
# Tweet Text:#EXCLUSIVE #news NOW!
# #Britain is looking for its citizens who are fighting for #UkraineRussiaWar as #NeoNazis, all those who return from the battlefield from #Ukraine are awaiting the #DeathPenalty.
#
# P.S. Don't worry #UK, all of them are dead in combating Russian Aggression!
# Hashtags Used:['EXCLUSIVE', 'news', 'Britain', 'UkraineRussiaWar', 'NeoNazis', 'Ukraine', 'DeathPenalty', 'UK']
#
# Tweet 47:
# Username:Bec57007377Beck
# Description:Former Hospital Corpsman/Single Father/2A guarantees 1A/God Wins
# Location:
# Following Count:514
# Follower Count:182
# Total Tweets:128
# Retweet Count:102
# Tweet Text:President Biden announced that the USA will pay billions of dollars for healthcare and retirement pensions for Ukrainian citizens to "keep #Ukraine stable."
#
# Do you support this?
# Hashtags Used:[]
#
# Tweet 48:
# Username:rramakoba
# Description:„Оног дана када наука почне да проучава нефизичке појаве, напредоваће више у једној деценији него у свим претходним вековима свог постојања. —Никола Тесла
# Location:Zeta Reticuli
# Following Count:4147
# Follower Count:1565
# Total Tweets:39794
# Retweet Count:16
# Tweet Text:Why Russia Went to War Now
# by Ted Snider
# #Ukraine #Russia #NATO
# https://t.co/mhSYkZiMbk https://t.co/kXz9HRLJfb
# Hashtags Used:['Ukraine', 'Russia', 'NATO']
#
# Tweet 49:
# Username:temptingtalk
# Description:Nurse Practitioner, animal lover and advocate. Proud Liberal. I love Rock & Roll and good Blues. Doing what I can to make this world a kinder place.
# Location:Los Angeles, CA
# Following Count:715
# Follower Count:205
# Total Tweets:6313
# Retweet Count:8
# Tweet Text:After a bombardment a cat got trapped in a destroyed building. These #Ukrainian heroes brought a crane and rescued the cat 🐈. #StandWithUkraine #CatsofTwittter #ukraine https://t.co/uQMkXF3T2V
# Hashtags Used:['Ukrainian']
#
# Tweet 50:
# Username:MaxMoznaim
# Description:Zionist
# Location:Frankfurt am Main
# Following Count:260
# Follower Count:34
# Total Tweets:976
# Retweet Count:350
# Tweet Text:The Prosecutor General's Office of #Ukraine reported finding the graves of two murdered men with traces of torture in the village of #Kalynivka, #Kyiv region. The men's hands were tied behind their backs, their nails were missing, and their bodies bore traces of gunshot wounds. https://t.co/kssvoIfMbM
# Hashtags Used:['Ukraine']
#
# Tweet 51:
# Username:SnowbergerJon1
# Description:I hate political games and the way the world is turning. Love my wife and dog in that order.👵🐶💛💙workaholic Democrat...I stand w/Ukraine & Democracy.
# Location:
# Following Count:2397
# Follower Count:601
# Total Tweets:18573
# Retweet Count:12
# Tweet Text:Russian FM Lavrov tells Italian media #Russia will not attempt to finish military operation in #Ukraine by May 9 (VE Day in Russia).
#
# Actually, it is clear Russia's military is not capable of achieving even down-sized goal of securing Donbas by May 9.
# Hashtags Used:['Russia', 'Ukraine']
#
# Tweet 52:
# Username:AlexAlmeida2020
# Description:Regional security analyst @hcaccess. Focused on Iraq/KRI, Yemen and Gulf states.
# Location:
# Following Count:1378
# Follower Count:15337
# Total Tweets:3003
# Retweet Count:952
# Tweet Text:#Ukraine: A curious buggy (all terrain vehicle) armed with a Stugna-P anti-tank guided missile was recently destroyed in the vicinity of Izium, #Kharkiv Oblast. Such vehicles are currently used by many Ukrainian hit-and-run and raid teams in the region. https://t.co/6JW9FbDpLB
# Hashtags Used:['Ukraine']
#
# Tweet 53:
# Username:gzechnas
# Description:Ganó el NO !!! Zurdos a seguir llorando
# Location:
# Following Count:2056
# Follower Count:1888
# Total Tweets:104680
# Retweet Count:215
# Tweet Text:Video from earlier today of precise Ukrainian artillery fire striking Russian equipment that attempted to advance in Kharkiv Oblast.
# #Russia #Ukraine https://t.co/VAQk9H8vMP
# Hashtags Used:[]
#
# Tweet 54:
# Username:PressenzaIPA
# Description:PRESSENZA is an International Press Agency specializing in news about Peace, Nonviolence, Humanism and Non-discrimination. This is our official twitter account.
# Location:Quito, Ecuador
# Following Count:616
# Follower Count:2074
# Total Tweets:15081
# Retweet Count:0
# Tweet Text:“No one can win this war. A negotiated, just peace guaranteed by EU-US-Russia is the only sane strategy” – CGTN interview https://t.co/KuuQDwiWZH #Europe #Ukraine #YanisVaroufakis CGTN China Global Television Network https://t.co/wFSSOWYaMX
# Hashtags Used:['Europe', 'Ukraine', 'YanisVaroufakis']
#
# Tweet 55:
# Username:Schmuley230
# Description:I am ginger kitty in the big city and living the dream!!!!!
# Location:Meow
# Following Count:2085
# Follower Count:84
# Total Tweets:9218
# Retweet Count:402
# Tweet Text:NEW: Pentagon says #Ukraine forces pushed #Russia 40km East of Kharkiv
#
# • ‘Incredible effort’ in last 48 hrs
# • Pushed to Donbas region
# • Russia progress ‘anemic’
# • Ru Generals been killed but US doesn’t have exact number
# • 80% of Howitzers delivered https://t.co/gwx7lrqksj
# Hashtags Used:['Ukraine', 'Russia']
#
# Tweet 56:
# Username:Fidget02
# Description:Digital forensics & aviation expert. Previously one of the top 57 pioneering female leaders in UK. https://t.co/PngHiJtvG4
# Location:UK
# Following Count:2947
# Follower Count:2732
# Total Tweets:54359
# Retweet Count:0
# Tweet Text:02/05/2022 #StandWithUkraine #Ukraine #DigitalResistance ** Verified** #Kharkiv #Izyum https://t.co/FZpdTanagP
# Hashtags Used:['StandWithUkraine', 'Ukraine', 'DigitalResistance', 'Kharkiv', 'Izyum']
#
# Tweet 57:
# Username:PolakWroc
# Description:Guy in Poland.
# Location:Poland
# Following Count:34
# Follower Count:2
# Total Tweets:629
# Retweet Count:380
# Tweet Text:#Ukraine: Some footage made its way to us from the famous Snake Island in the Black Sea.
#
# Here's a Ukrainian Bayraktar TB-2 drone strike a few days ago against a Russian ZU-23-2 autocannon position- during the same event a Strela-10 SAM system was struck. https://t.co/w0zuKFzsnA
# Hashtags Used:['Ukraine']
#
# Tweet 58:
# Username:RowiClarck
# Description:
# Location:
# Following Count:50
# Follower Count:0
# Total Tweets:253
# Retweet Count:27
# Tweet Text:Another Ukrainian TB2 strike in Snake Island, also via @UAWeapons.
#
# As a result a Russian 9K35 Strela-10 SAM system was destroyed.
# #Russia #Ukraine https://t.co/gKONVAnUrY
# Hashtags Used:[]
#
# Tweet 59:
# Username:TheRorschach1
# Description:"If the road you followed brought you to this, of what use was the road? The Great Philosopher Anton Chigurh
# Location:Dry Prong, LA
# Following Count:1218
# Follower Count:906
# Total Tweets:11167
# Retweet Count:5104
# Tweet Text:UPDATE - Yesterday's #Ukraine attack on the Rus. HQ in #Izium was designed to liquidate the high-value target - chief of Gen. Staff of RAF Gen. Valeriy Gerasimov. The Kremlin sent him to get a victory for the May 9 parade. Gerasimov was close to the blast but wounded. [Thread⬇️] https://t.co/vYgZQRoML3
# Hashtags Used:['Ukraine', 'Izium']
#
# Tweet 60:
# Username:panos19877236
# Description:
# Location:Athens, GA
# Following Count:395
# Follower Count:123
# Total Tweets:32507
# Retweet Count:35
# Tweet Text:Find someone in life that looks at you the way @RepAdamSchiff looks at Zelensky. It's a FREAK SHOW #ukraine https://t.co/Ci8jbRsQlE
# Hashtags Used:['ukraine']
#
# Tweet 61:
# Username:marcelloc24
# Description:
# Location:
# Following Count:2463
# Follower Count:451
# Total Tweets:2633
# Retweet Count:1
# Tweet Text:How @EmmanuelMacron stole #FrenchElection2022 from @MLP_officiel: #Macron kept an ultra-secret. Ca. 50 #French #Military, supervising #Ukrainianwar against #Russia, are trapped with #AzovNazis at #Azovstal steel mill plant in #Mariupol #Ukraine surrounded by #RussianArmy. #LePen https://t.co/q7b8yA9tOd
# Hashtags Used:['FrenchElection2022', 'Macron', 'French', 'Military']
#
# Tweet 62:
# Username:Romanselydove
# Description:Юрист
# Location:Селидове
# Following Count:385
# Follower Count:162
# Total Tweets:70421
# Retweet Count:256
# Tweet Text:#Ukraine: A Russian vehicle of unknown type was destroyed by precise Ukrainian artillery fire on the Eastern front. https://t.co/zhpqNCULyh
# Hashtags Used:['Ukraine']
#
# Tweet 63:
# Username:Ferbeltranmx
# Description:#AntiAMLO 100%
#
# Digital Marketing Strategist,
# SAP Demand Generation Expert, #F1 Fan
#
# I tweet on #SAP #Technology #Politics
#
# #Fotógrafo sígueme en IG
# Location:Mexico City
# Following Count:5755
# Follower Count:5423
# Total Tweets:27381
# Retweet Count:14
# Tweet Text:Here is the video evidence of how the #Ukraine AF destroyed the Russian anti-air "Strela-10" (S-13 Gopher) on the Snake Island in the Black Sea. UAF used Turkish drone #Bayraktar TB2 &amp; fired a missile from an almost service ceiling of 7 km. https://t.co/ZSpsymw0Fe https://t.co/LZqYICw2fd
# Hashtags Used:['Ukraine']
#
# Tweet 64:
# Username:artpontos
# Description:
# Location:
# Following Count:52
# Follower Count:12
# Total Tweets:128
# Retweet Count:86
# Tweet Text:The Ukranian citizens of Mariupol speak: "We want to see the captured Ukranian Azov soldiers paraded in the Victory Day parade so at least we can split in their faces for what they have done to us" #Azovstal #ukraine #UkraineRussiaWar #mariupol #azov https://t.co/jHRLal7dsg
# Hashtags Used:[]
#
# Tweet 65:
# Username:CrowdVectors
# Description:
# Location:
# Following Count:28
# Follower Count:479
# Total Tweets:166356
# Retweet Count:0
# Tweet Text:5 MVPs from opening round of the 2022 NBA Playoffs    Get Instant Access Now! ==&gt; *** https://t.co/94zfmXtkQJ *** #nba #Basketball #basketballcardscards #celtics #bucks #youtube #nets #warriors #lakers #russia #ukraine #war # #Kyiv
# Hashtags Used:['nba', 'Basketball', 'basketballcardscards', 'celtics', 'bucks', 'youtube', 'nets', 'warriors', 'lakers', 'russia', 'ukraine', 'war', 'Kyiv']
#
# Tweet 66:
# Username:Alicebellamy
# Description:Learning 💯 🙏RT don’t just like posts🙏 an #ExcludedUK Sole Ltd Director & Therapist @ Woman to Woman & The Male Perspective Laser Hair Removal & Beauty Studio
# Location:Calne, England SN11 8LJ
# Following Count:4910
# Follower Count:2633
# Total Tweets:129132
# Retweet Count:14
# Tweet Text:Here is the video evidence of how the #Ukraine AF destroyed the Russian anti-air "Strela-10" (S-13 Gopher) on the Snake Island in the Black Sea. UAF used Turkish drone #Bayraktar TB2 &amp; fired a missile from an almost service ceiling of 7 km. https://t.co/ZSpsymw0Fe https://t.co/LZqYICw2fd
# Hashtags Used:['Ukraine']
#
# Tweet 67:
# Username:Greene_Thoughts
# Description:Difficult.Enigma.Make friends fast enemies faster.
# Earth Healer
# 'Patience without strife'
# 'What you are afraid to criticize controls you'
# Location:
# Following Count:5000
# Follower Count:827
# Total Tweets:121670
# Retweet Count:6
# Tweet Text:2/20 It was a fascinating week for those who analyse the war in #Ukraine. First, President Biden sent a request to Congress for US$33 billion dollars in military, economic and humanitarian aid for Ukraine. Then, the US Congress approved new Lend Lease legislation.
# Hashtags Used:['Ukraine']
#
# Tweet 68:
# Username:Joope_BJW
# Description:💪 🌈 👨‍❤️‍💋‍👨 #FBPE #Ateizm
# https://t.co/cRJHFD7TN6
# RESET OBYWATELSKI
# https://t.co/jqlXLfhAtA
# https://t.co/dBKGrajK7p
# Location:Warszawa, PL
# Following Count:2012
# Follower Count:1888
# Total Tweets:119141
# Retweet Count:61
# Tweet Text:Goodnight #Ukraine. Just a reminder. https://t.co/LjhaGzSSTk
# Hashtags Used:['Ukraine']
#
# Tweet 69:
# Username:JMMaza1
# Description:Mens sana in corpore crado
# Location:
# Following Count:498
# Follower Count:176
# Total Tweets:8411
# Retweet Count:1199
# Tweet Text:My thoughts on some potential #Neocon objectives. #Zelenskyy #Putin #Ukraine #Donbass #Russia #VictoriaNuland https://t.co/rC0EZbNO06
# Hashtags Used:['Neocon', 'Zelenskyy', 'Putin', 'Ukraine', 'Donbass', 'Russia', 'VictoriaNuland']
#
# Tweet 70:
# Username:RuthTweetX
# Description:
# Location:
# Following Count:242
# Follower Count:219
# Total Tweets:21503
# Retweet Count:2
# Tweet Text:Meet Hurrem Sultan, also known as Roksolana, born in #Ukraine in the beginning of the XVI century. She was the wife of Ottoman Emperor Suleiman the Magnificent. She became the first woman in the history of the East who shared the right of rule with her husband. #MetGala2022 https://t.co/WUOCTj171Y https://t.co/RWObhL84ho
# Hashtags Used:['Ukraine']
#
# Tweet 71:
# Username:colour171207
# Description:schilder, schrijver.   Vrijheid in het geestesleven,  gelijke rechten voor iedereen,  solidariteit in economie.
# Location:
# Following Count:1112
# Follower Count:277
# Total Tweets:59043
# Retweet Count:14
# Tweet Text:Here is the video evidence of how the #Ukraine AF destroyed the Russian anti-air "Strela-10" (S-13 Gopher) on the Snake Island in the Black Sea. UAF used Turkish drone #Bayraktar TB2 &amp; fired a missile from an almost service ceiling of 7 km. https://t.co/ZSpsymw0Fe https://t.co/LZqYICw2fd
# Hashtags Used:['Ukraine']
#
# Tweet 72:
# Username:StecSlawomir
# Description:🇵🇱 Strefa wolna od postkomuny... agregacja treści prawicowych...
# Location:
# Following Count:5061
# Follower Count:4604
# Total Tweets:48733
# Retweet Count:12
# Tweet Text:Excellent news for #Ukraine. Less risk of Germany hijacking any so-called diplomatic process to pressure #Ukraine into a "peace-agreement", just to give #Putin parts already invaded &amp; bring back 'business as usual'.
# Declining #Steinmeier's visit was a brilliant move. https://t.co/RXfaYmXa5M
# Hashtags Used:['Ukraine', 'Ukraine']
#
# Tweet 73:
# Username:fosfool
# Description:Donate to help people of Ukraine 🇺🇦
# https://t.co/nnIzOHxe6e
# Paypal accepted!
# Tax receipt provided.
# Help now!
# Sponsored by Mila Kunis and Ashton Kutcher
# Location:United States
# Following Count:201
# Follower Count:104
# Total Tweets:7869
# Retweet Count:58
# Tweet Text:Good night, and Glory to #Ukraine 🇺🇦✊🏻 https://t.co/q6GyABwkwr
# Hashtags Used:['Ukraine']
#
# Tweet 74:
# Username:RowiClarck
# Description:
# Location:
# Following Count:50
# Follower Count:0
# Total Tweets:253
# Retweet Count:86
# Tweet Text:More footage of Ukrainian Bayraktar TB2 drone, striking a Russian ZU-23-2 AA gun a few days ago in Snake Island.
# Via @UAWeapons
# #Russia #Ukraine https://t.co/iAXmC2aFrP
# Hashtags Used:[]
#
# Tweet 75:
# Username:LucyMyArts
# Description:
# Location:London
# Following Count:2555
# Follower Count:1404
# Total Tweets:23510
# Retweet Count:8
# Tweet Text:#Lavrov engaging in anti-Semiticism to justify brutal aggression against #Ukraine claiming Hitler was Jewish!!! All in a bid to justify shameful claim engaged in “denazification” slaughtering civilians incl children+women b/c #Zelensky is Jewish #RussianWarCrimes #Mariupol #Bucha https://t.co/9B1L69W4D5
# Hashtags Used:['Lavrov', 'Ukraine']
#
# Tweet 76:
# Username:acoastwalker
# Description:The Coastwalker
# Location:UK
# Following Count:133
# Follower Count:22
# Total Tweets:7478
# Retweet Count:350
# Tweet Text:The Prosecutor General's Office of #Ukraine reported finding the graves of two murdered men with traces of torture in the village of #Kalynivka, #Kyiv region. The men's hands were tied behind their backs, their nails were missing, and their bodies bore traces of gunshot wounds. https://t.co/kssvoIfMbM
# Hashtags Used:['Ukraine']
#
# Tweet 77:
# Username:LimoGame
# Description:#HospitalityStrong / #Network2Success / #SocialMedia / #Sales / #BusinessTravel / #Travel / #Events / #bbTwitterTip /#EstateSales / #LimoStrong / Tweets-R-Mine
# Location:USA
# Following Count:5017
# Follower Count:4575
# Total Tweets:31330
# Retweet Count:1
# Tweet Text:Hoping they all heard #TrevorNoah and will now take his lesson to heart. Reporting the truth should never be so hard. #FreedomOfSpeech #Ukraine https://t.co/gNxEb2YtFr
# Hashtags Used:['TrevorNoah']
#
# Tweet 78:
# Username:maisalena3
# Description:
# Location:
# Following Count:142
# Follower Count:92
# Total Tweets:2072
# Retweet Count:19
# Tweet Text:In an interview with current "Jewish" president of Ukraine #Zelensky, he calls Stephan Bandera an undeniable hero of #Ukraine. 🤮🤢
#
# #Bandera is a Ukrainian responsible for the death of some 100,000 #Poles.
#
# #Poland #Putin #Hitler #Azov #Russia #Germany https://t.co/qXAWkr3Gec
# Hashtags Used:['Zelensky']
#
# Tweet 79:
# Username:wiseowl60
# Description:US State Dept 15+ yrs. Central America & Europe
# Location:
# Following Count:232
# Follower Count:355
# Total Tweets:62812
# Retweet Count:124
# Tweet Text:So let's sum shit up.
#
# #Anonymous released millions of Russian data, FSB rats and military (rapist's) officials. Multi billion corps data breaches and several infrastructures where and are stil offline and @mfa_russia still doesn't get it.
#
# Get your shit out of #Ukraine
# Hashtags Used:['Anonymous']
#
# Tweet 80:
# Username:NFTwelfare
# Description:NFT Enthousiast, Promoter and Content Creator. I love art in general. Hopefully I can make a living with this some day. #nftcommunity #nft #nfts 500+ pics a day
# Location:everywhere
# Following Count:580
# Follower Count:565
# Total Tweets:4937
# Retweet Count:0
# Tweet Text:#NFT #NFTs #NFTCommunity #NFTGiveaways #NFTCommumity #NFTartist #nftart #nftdrop #bitcoin #btc #bayc #apecoin #Ukraine #opensea #polygon
# https://t.co/WH1vWWn5JW
# Drop your NFT ✍️🤓👀🔥🥸🇺🇦 https://t.co/dJ4LF3smmv
# Hashtags Used:['NFT', 'NFTs', 'NFTCommunity', 'NFTGiveaways', 'NFTCommumity', 'NFTartist', 'nftart', 'nftdrop', 'bitcoin', 'btc', 'bayc', 'apecoin', 'Ukraine', 'opensea', 'polygon']
#
# Tweet 81:
# Username:machonejack
# Description:A Teamster, & US Navy Vet. & a mechanic that Loves Mustangs & garage time repairs,missing the 80's.
# Location:louisville ky
# Following Count:12094
# Follower Count:11034
# Total Tweets:377587
# Retweet Count:10
# Tweet Text:@CitizensFedUp @Juanita21272085 @co_rapunzel4 @SharesTruth @Kris_Sacrebleu @MtnMD @ReduxPanda @POTUS #WomensHealth #FBI #Veterans #Law #USMC #NAVY #Hispanic #Latino #Latinos #NoBallsDonnie #DementiaDon #BanFoxFromBases #Ukraine #Midterms2022
#
# UNITED WE STAND
# PUSH FOR VOTER PROTECTIONS
# https://t.co/xzuR77yVt1
# Hashtags Used:['WomensHealth', 'FBI']
#
# Tweet 82:
# Username:EretzIsrael
# Description:🇮🇱  (RT & Following ≠ Endorsement)
# Location:ישראל
# Following Count:651
# Follower Count:11068
# Total Tweets:14833
# Retweet Count:1
# Tweet Text:"The Ghost of Kyiv is a superhero-legend, whose character was created by Ukrainians!” #Ukraine’s Air Force Command wrote on Facebook. It's believed no pilot in the 21st century has ever shot down five or more enemy jets. #UkraineRussiaWar
# Hashtags Used:['Ukraine']
#
# Tweet 83:
# Username:ap4aaa
# Description:Marginal artdirector
# Location:Lost in cyberspace
# Following Count:373
# Follower Count:150
# Total Tweets:88878
# Retweet Count:831
# Tweet Text:This man has been working every single day of war. Every time we felt scared, depressed, disappointed, upset - he would just get up and open his booth and sell fruit and veggies.
# I bow to all people of #Ukraine who never stopped working. Never stopped building and moving forward. https://t.co/EKZ46SA0WU
# Hashtags Used:[]
#
# Tweet 84:
# Username:johnyankee083
# Description:Archaeologist of Knowledge 58%HomoSapiens20%AtheisticHumanist6%Awkward15%Bookish
# 1%PewterBadgeBoonie:100%LongLiveUkraine🇺🇦
# Location:LandOFshameForFailingUkraine
# Following Count:88
# Follower Count:158
# Total Tweets:5748
# Retweet Count:129
# Tweet Text:Civic #journalist Iryna #Danilovych disappears after being seized in #Russia occupied #Crimea
# #Ukraine #FreeDanilovych #LetMyPeopleGo #StandWithUkraine
# https://t.co/qSMpsfsNPB https://t.co/pBw3EjzdJn
# Hashtags Used:['journalist', 'Danilovych', 'Russia', 'Crimea', 'Ukraine', 'FreeDanilovych']
#
# Tweet 85:
# Username:Hiwet_Tgraweti
# Description:Tgraweti_❤💛💪
# #StopTigrayGenocide
# Location:
# Following Count:557
# Follower Count:413
# Total Tweets:27268
# Retweet Count:82
# Tweet Text:|'All attention to #Ukraine is very important, of course, because it impacts the whole world. But even a fraction of it is not being given to #Tigray, #Yemen, #Afghanistan, #Syria' @MinorityRights @ActionAidUK @trussliz @jeremycorbyn #TigrayGenocide https://t.co/IgQ37y1Yzs
# Hashtags Used:['Ukraine']
#
# Tweet 86:
# Username:DianeSare
# Description:Diane Sare, #Independent candidate for US Senate-NY 2022, #LaRouche Organization Manhattan Project, Pass #GlassSteagall, and return to a #NationalBank !
# Location:Ramapo, NY
# Following Count:2932
# Follower Count:4211
# Total Tweets:4606
# Retweet Count:15
# Tweet Text:Why do I support @DianeSare? Take a seat.
#
# #AntiWar #AntiSanctions #AntiWallStreet #AntiBailouts #Infrastructure #Taxes #Peace #Development #NewYork #Senate #NYC #WallStreet #Economics #Russia #Ukraine #UkraineRussiaWar #RussiaUkraineWar #Solutions #WhyDiane @SchillerInstit1 https://t.co/O5kwJ7Q5SR
# Hashtags Used:['AntiWar', 'AntiSanctions', 'AntiWallStreet', 'AntiBailouts', 'Infrastructure']
#
# Tweet 87:
# Username:IreneNik2
# Description:
# Location:
# Following Count:11
# Follower Count:2
# Total Tweets:26
# Retweet Count:3921
# Tweet Text:All those missiles #Russia launched on #Ukraine cost USD $7,5 BILLION . All that could have been spent on hospitals and schools for ordinary Russians. But no, that nation thinks killing Ukrainians is a much better idea
# Hashtags Used:['Russia', 'Ukraine']
#
# Tweet 88:
# Username:OakleyMombo
# Description:Canadian humanoid
# Location:
# Following Count:41
# Follower Count:29
# Total Tweets:1076
# Retweet Count:1732
# Tweet Text:#Azovstal ✊🏻🇺🇦
#
# Glory to #Ukraine, glory to Heroes! https://t.co/DkuFoao4yt
# Hashtags Used:['Azovstal', 'Ukraine']
#
# Tweet 89:
# Username:chickie2x4
# Description:D.A.R. Granny, Mom 🐕🐕🌎🌊🔪
# Location:The Redwoods Ca
# Following Count:3667
# Follower Count:1914
# Total Tweets:8864
# Retweet Count:507
# Tweet Text:Just your everyday #Ukrainian hero transporting a couple of freshly caught #Russian POWs.
#
# Glory to #Ukraine 🇺🇦✊🏻 https://t.co/IbdfHR4EKI
# Hashtags Used:['Ukrainian', 'Russian', 'Ukraine']
#
# Tweet 90:
# Username:Sara1Axumawit
# Description:
# Location:
# Following Count:1445
# Follower Count:1053
# Total Tweets:37483
# Retweet Count:78
# Tweet Text:#humanitycomesfirst As the world focuses on #Ukraine, we urge #AusGov &amp; UN members to not forget Tigray, a region cut off from the world. Very little aid has entered the region, #AusGov can do more! #TigrayCantWait #AusPol #AusGovActNow @MarisePayne @dfat @scottmorrisonMP
# Hashtags Used:['humanitycomesfirst', 'Ukraine', 'AusGov']
#
# Tweet 91:
# Username:NFTwelfare
# Description:NFT Enthousiast, Promoter and Content Creator. I love art in general. Hopefully I can make a living with this some day. #nftcommunity #nft #nfts 500+ pics a day
# Location:everywhere
# Following Count:580
# Follower Count:565
# Total Tweets:4937
# Retweet Count:0
# Tweet Text:#NFT #NFTs #NFTCommunity #NFTGiveaways #NFTCommumity #NFTartist #nftart #nftdrop #bitcoin #btc #bayc #apecoin #Ukraine #opensea #polygon
# https://t.co/WH1vWWn5JW
# Drop your NFT ✍️🤓👀🔥🥸🇺🇦 https://t.co/AsgFhAfoxR
# Hashtags Used:['NFT', 'NFTs', 'NFTCommunity', 'NFTGiveaways', 'NFTCommumity', 'NFTartist', 'nftart', 'nftdrop', 'bitcoin', 'btc', 'bayc', 'apecoin', 'Ukraine', 'opensea', 'polygon']
#
# Tweet 92:
# Username:Ashrafi4ever
# Description:Activist | Freedom-Fighter
# Fighting for the day that no little girl will have to lose her father to the gallows
# #IStandWithMaryamRajavi
# FA: @ZolalHabibi
# Location:Global Citizen
# Following Count:3360
# Follower Count:3684
# Total Tweets:55178
# Retweet Count:6
# Tweet Text:#StandWithUkraine
# Let's applaud the brave people of #Ukraine, @ZelenskyyUa, and everyone who dedicated his soul to the cause of #Freedom, #Independence, and #Democracy.
#
# "We have to prepare to fight... Pull triggers... Victory is our sole aim," the song heard. https://t.co/Wt9WOpKavG
# Hashtags Used:['StandWithUkraine', 'Ukraine']
#
# Tweet 93:
# Username:idawhannadoyou
# Description:Account permanently suspended in Oct. 2020 for tweeting about Hunter's laptop. Account restored April 2022.
# Location:
# Following Count:7010
# Follower Count:6811
# Total Tweets:350889
# Retweet Count:1199
# Tweet Text:My thoughts on some potential #Neocon objectives. #Zelenskyy #Putin #Ukraine #Donbass #Russia #VictoriaNuland https://t.co/rC0EZbNO06
# Hashtags Used:['Neocon', 'Zelenskyy', 'Putin', 'Ukraine', 'Donbass', 'Russia', 'VictoriaNuland']
#
# Tweet 94:
# Username:HitechguruS
# Description:IT Architect, Security, Gentle Giant, very witty & Humourous, Environment Friendly, Green Technology, Sustainability, Simple lifestyle, Healthy living
# Location:Toronto, Canada
# Following Count:224
# Follower Count:55
# Total Tweets:11559
# Retweet Count:0
# Tweet Text:Does #VladimirPutin have an #endgame in #Ukraine? The next few #weeks are #crucial https://t.co/VEOIaIMgRX #Putin #Zelenskyy #UkraineRussianWar #Kyiv #RussiaUkraineWarupdate #WorldWarIII #WWIII #WW3 #UkraineUnderAttaсk #War #nuclearwar #NuclearWeapons #nukes #nuclearbomb #Nuclear
# Hashtags Used:['VladimirPutin', 'endgame', 'Ukraine', 'weeks', 'crucial', 'Putin', 'Zelenskyy', 'UkraineRussianWar', 'Kyiv', 'RussiaUkraineWarupdate', 'WorldWarIII', 'WWIII', 'WW3', 'UkraineUnderAttaсk', 'War', 'nuclearwar', 'NuclearWeapons', 'nukes', 'nuclearbomb', 'Nuclear']
#
# Tweet 95:
# Username:Fidget02
# Description:Digital forensics & aviation expert. Previously one of the top 57 pioneering female leaders in UK. https://t.co/PngHiJtvG4
# Location:UK
# Following Count:2947
# Follower Count:2732
# Total Tweets:54359
# Retweet Count:0
# ...
# Location:Heart of the Sacramento Delta
# Following Count:61
# Follower Count:19
# Total Tweets:6377
# Retweet Count:90
# Tweet Text:#Ukraine: A Ukrainian BTR-70 armored personnel carrier was recently captured by the Russian army near Lyman, #Donestk Oblast. https://t.co/Nyf4Z5Vwxl
# Hashtags Used:['Ukraine', 'Donestk']
#
# Tweet 968:
# Username:Joannawinterbou
# Description:European 💪🇪🇺 Stamford beautiful place to live😐💙Labour Town councillor
# Location:Stamford
# Following Count:2488
# Follower Count:1232
# Total Tweets:120277
# Retweet Count:28
# Tweet Text:More dreadful stories of #WarCrimes in #Mariupol  on BBC 1 News. We must not flinch from doing everything we can to support the people of #Ukraine in their fight against Russia’s barbaric illegal invasion. #PutinWarCriminal
# Hashtags Used:['WarCrimes', 'Mariupol']
#
# Tweet 969:
# Username:PeraPer21966641
# Description:
# Location:
# Following Count:249
# Follower Count:45
# Total Tweets:3471
# Retweet Count:368
# Tweet Text:While "#Russia has paid more than 70 million Rubles to Ukrainian pensioners and state employees", #Ukraine has forsaken some of these territories long ago and is now cutting mobile communication in some areas taken by Russia. You don't do this if you want your territories back.
# Hashtags Used:['Russia', 'Ukraine']
#
# Tweet 970:
# Username:TheHidingGhost
# Description:Citadel Graduate. Political Science Major. Intel Officer. My opinions are my own.
# Location:
# Following Count:2096
# Follower Count:973
# Total Tweets:10646
# Retweet Count:404
# Tweet Text:NEW: Pentagon says #Ukraine forces pushed #Russia 40km East of Kharkiv
#
# • ‘Incredible effort’ in last 48 hrs
# • Pushed to Donbas region
# • Russia progress ‘anemic’
# • Ru Generals been killed but US doesn’t have exact number
# • 80% of Howitzers delivered https://t.co/gwx7lrqksj
# Hashtags Used:['Ukraine', 'Russia']
#
# Tweet 971:
# Username:1Suffolks1915
# Description:Love of History & Military History, The Suffolk Regiment, Royal Anglian Regiment. UK Chair for Company Veterans Group. Enthused military storyteller.
# Location:
# Following Count:44
# Follower Count:97
# Total Tweets:302
# Retweet Count:0
# Tweet Text:Latest UK Defence Intelligence Map on the situation in Ukraine - 02 May 2022
#
# #ukraine #mod #Donetsk #Luhansk #Kyiv #Kharkiv #UK #UkraineRussiaWar #UkraineWar #kramatorsk #Mariupol #Donbas https://t.co/QhrfTotT5C
# Hashtags Used:['ukraine', 'mod', 'Donetsk', 'Luhansk', 'Kyiv', 'Kharkiv', 'UK', 'UkraineRussiaWar', 'UkraineWar', 'kramatorsk', 'Mariupol', 'Donbas']
#
# Tweet 972:
# Username:Navsteva
# Description:https://t.co/fbb1q4QhuB
#
# #BeltandRoad #EAEU #OBOR #BRI | World landbridge https://t.co/uFlOu8vnSW
# Location:Kiev, West Russia
# Following Count:2190
# Follower Count:18349
# Total Tweets:22085
# Retweet Count:9
# Tweet Text:I will try to provide a #SitRep, as usual, later in the evening. Justice for the #Odessa victims of #Ukraine|ian #Nazi|s draws ever nearer to exacting its vengeance. #NeverForget #NeverForgive Odessa #May2
# Hashtags Used:['SitRep', 'Odessa', 'Ukraine', 'Nazi']
#
# Tweet 973:
# Username:gnatalieca
# Description:
# Location:California, USA
# Following Count:2500
# Follower Count:1533
# Total Tweets:10844
# Retweet Count:124
# Tweet Text:So let's sum shit up.
#
# #Anonymous released millions of Russian data, FSB rats and military (rapist's) officials. Multi billion corps data breaches and several infrastructures where and are stil offline and @mfa_russia still doesn't get it.
#
# Get your shit out of #Ukraine
# Hashtags Used:['Anonymous']
#
# Tweet 974:
# Username:pis_u
# Description:✴️✴️✴️✴️✴️ ✴️✴️✴️
# i się nie bać‼️
# #pis 👉#WYPIERDALAĆ‼️
# #ATHEIZM #religionkills
# pedofilskie mendy w koloratkach #kk #CzarnaSektaPedofilska 👉 #WYPIERDALAĆ‼️⚡⚡
# Location:
# Following Count:5638
# Follower Count:8388
# Total Tweets:444216
# Retweet Count:61
# Tweet Text:Goodnight #Ukraine. Just a reminder. https://t.co/LjhaGzSSTk
# Hashtags Used:['Ukraine']
#
# Tweet 975:
# Username:MixedPickles
# Description:We don't see things as they are , we see them as we are - Anais Min
# Location:Düsseldorf, Germany
# Following Count:436
# Follower Count:32
# Total Tweets:2576
# Retweet Count:0
# Tweet Text:@hartaberfair @Afelia @DasErste “The world will not be destroyed by those who do evil, but by those who watch them without doing anything.” Albert Einstein
#
# #teardownthiswall #stoprussianwar #kyjiw #bucha #irpin #mariupol #kramatorsk #voelkermord #ukraine #nfz
#
# @Bundeskanzler @BMWK
#
# https://t.co/KuvLwpzcqD
# Hashtags Used:['teardownthiswall', 'stoprussianwar', 'kyjiw', 'bucha', 'irpin', 'mariupol', 'kramatorsk', 'voelkermord', 'ukraine', 'nfz']
#
# Tweet 976:
# Username:HysoSophism
# Description:Former @UKSophism suspended account
# Location:
# Following Count:1496
# Follower Count:711
# Total Tweets:12332
# Retweet Count:66
# Tweet Text:#Ukraine: Ukrainian forces destroyed a #Russia-n 9K35 Strela-10 anti aircraft system earlier in Chernihiv oblast. This is the third one visually confirmed destroyed on the Russian side. https://t.co/KDxyenp0ay
# Hashtags Used:['Ukraine', 'Russia']
#
# Tweet 977:
# Username:ybRmjRBuYIcJT40
# Description:
# Location:
# Following Count:60
# Follower Count:19
# Total Tweets:6812
# Retweet Count:223
# Tweet Text:#Ukraine: A Russian armoured Ural-4320 Zvezda-V truck was destroyed by the Ukrainian forces- precise date and location unknown. https://t.co/VtjUdXd3op
# Hashtags Used:['Ukraine']
#
# Tweet 978:
# Username:Navsteva
# Description:https://t.co/fbb1q4QhuB
#
# #BeltandRoad #EAEU #OBOR #BRI | World landbridge https://t.co/uFlOu8vnSW
# Location:Kiev, West Russia
# Following Count:2190
# Follower Count:18349
# Total Tweets:22085
# Retweet Count:49
# Tweet Text:Sorry for no updates today. I spent what little time I had translating this poem by Vadim #Negaturov, who was burned alive by #Ukraine|ian fascists, along with over 200 other victims, in the #Odessa #Khatyn Massacre of May 2, 2014. I felt it was more important to pay this homage. https://t.co/3nMwvKsnqY
# Hashtags Used:['Negaturov']
#
# Tweet 979:
# Username:THEMissB_says
# Description:Movies News US & World News Opinion News Political News Weather Technology & Science Movies
# Location:My Own Universe
# Following Count:3666
# Follower Count:176
# Total Tweets:55215
# Retweet Count:834
# Tweet Text:This man has been working every single day of war. Every time we felt scared, depressed, disappointed, upset - he would just get up and open his booth and sell fruit and veggies.
# I bow to all people of #Ukraine who never stopped working. Never stopped building and moving forward. https://t.co/EKZ46SA0WU
# Hashtags Used:[]
#
# Tweet 980:
# Username:patriciaewelch
# Description:
# Location:
# Following Count:746
# Follower Count:323
# Total Tweets:30376
# Retweet Count:1203
# Tweet Text:My thoughts on some potential #Neocon objectives. #Zelenskyy #Putin #Ukraine #Donbass #Russia #VictoriaNuland https://t.co/rC0EZbNO06
# Hashtags Used:['Neocon', 'Zelenskyy', 'Putin', 'Ukraine', 'Donbass', 'Russia', 'VictoriaNuland']
#
# Tweet 981:
# Username:TeresaWeath
# Description:#UltraRemainer, #GTTO, #JohnsonOut, #ToryScum, #BrexitLies, I hate Tories
# Location:UK
# Following Count:4965
# Follower Count:2804
# Total Tweets:188205
# Retweet Count:12
# Tweet Text:Against all of his wishes, #BorisJohnson will forever be remembered for #Partygate. #Brexit yes, #Ukraine maybe, #covid possibly, but mainly the first #PM to break the law over and over again through partygate.
#
# Make you proud?
#
# MAKE SURE YOU #VOTE
# Hashtags Used:['BorisJohnson', 'Partygate', 'Brexit', 'Ukraine']
#
# Tweet 982:
# Username:Hauntedrose
# Description:
# Location:Heart of the Sacramento Delta
# Following Count:61
# Follower Count:19
# Total Tweets:6377
# Retweet Count:256
# Tweet Text:#Ukraine: A Russian vehicle of unknown type was destroyed by precise Ukrainian artillery fire on the Eastern front. https://t.co/zhpqNCULyh
# Hashtags Used:['Ukraine']
#
# Tweet 983:
# Username:victoria_scherr
# Description:Pro-Woman. Anti-Discrimination. Pro Choice.
# Location:
# Following Count:544
# Follower Count:1008
# Total Tweets:304912
# Retweet Count:801
# Tweet Text:Invaders destroy the historical heritage of Ukraine
#
# The #Russians destroyed the building of the 19th century #Lisichansk gymnasium, which was built by Belgian masters.
#
# It was one of the most beautiful schools in #Ukraine. https://t.co/0NrzBajUzN
# Hashtags Used:['Russians', 'Lisichansk']
#
# Tweet 984:
# Username:Stephen87165188
# Description:AGI researcher, former DARPA projects contributor. Curating tweets that explain the certain Ukrainian victory.
# Location:Rocky Mountains, USA
# Following Count:77
# Follower Count:201
# Total Tweets:7674
# Retweet Count:3
# Tweet Text:Wartime racism: #russian "federation" send small peoples to die in #Ukraine
#
# https://t.co/zRexJRBkc1
# #RussiaFakeState #RussiaTerroristState #StopRussia #StandWithUkraine #ArmUkraineNow #ArmUkraine #UkrainianArmy
# Hashtags Used:['russian', 'Ukraine', 'RussiaFakeState']
#
# Tweet 985:
# Username:vjmrkymrykm5km
# Description:yj35
# Location:
# Following Count:548
# Follower Count:153
# Total Tweets:3704
# Retweet Count:10
# Tweet Text:Remembering the American woman who begged me for money! #LOL
#
# #Mariupol
# #Ukraine #Russia https://t.co/NaYJsW6QeP
# Hashtags Used:['LOL', 'Mariupol', 'Ukraine', 'Russia']
#
# Tweet 986:
# Username:Diplomacy140
# Description:Reshaping the World: Ethics, Global Governance, Policy & Strategy in the New Millennium, Editor Pedro Meléndez-Ortiz #DigitalDiplomacy
# Location:London, England
# Following Count:1786
# Follower Count:3959
# Total Tweets:121687
# Retweet Count:0
# Tweet Text:Join @AndrzejDuda &amp; me in #Warsaw, #Poland for a photo opp before we hold a bilateral meeting with our Congressional delegation to discuss our ongoing partnership to support #Ukraine as it defends itself against #Putin’s illegal invasion.
#
# @SpeakerPelosi
#
# https://t.co/yEqDJvrirD
# Hashtags Used:['Warsaw', 'Poland', 'Ukraine', 'Putin']
#
# Tweet 987:
# Username:SustainablDylan
# Description:Follow This Account For More News On The #EndGame.....
# Location:Where The #MadMonkeys #Play
# Following Count:9012
# Follower Count:7586
# Total Tweets:154952
# Retweet Count:1
# Tweet Text:Dan Kovalik: 71 years of RFE/RL: How the #CIA-Founded American Media Outlet Survived the Soviet Collapse to Fight Cold War 2.0 https://t.co/MPSc78aayQ #Russia #Ukraine
# Hashtags Used:['CIA']
#
# Tweet 988:
# Username:Jonovistr
# Description:
# Location:
# Following Count:79
# Follower Count:28
# Total Tweets:5568
# Retweet Count:27
# Tweet Text:Another Ukrainian TB2 strike in Snake Island, also via @UAWeapons.
#
# As a result a Russian 9K35 Strela-10 SAM system was destroyed.
# #Russia #Ukraine https://t.co/gKONVAnUrY
# Hashtags Used:[]
#
# Tweet 989:
# Username:syntaxparse
# Description:
# Location:
# Following Count:75
# Follower Count:3
# Total Tweets:38
# Retweet Count:311
# Tweet Text:The 23-year-old nurse from Lysychansk (Luhansk region) Oksana, who lost both of her legs and 4 fingers in a mine explosion a month ago, today marries her sweetheart Victor in Lviv hospital. This is their first dance as newlyweds 💔 😭
# #Ukraine #StopRussiaNow #UkraineRussiaWar https://t.co/BiDiH3gUZT
# Hashtags Used:[]
#
# Tweet 990:
# Username:dastmalchif
# Description:Advocate of regime change in Iran, Transportation / Hydraulic Engineer & member of @IACNorCal
# Location:Sacramento, CA
# Following Count:618
# Follower Count:521
# Total Tweets:116672
# Retweet Count:2
# Tweet Text:@VidalQuadras :
# #Resistance in #Ukraine Has Brought #Iran’s Regime to Its Heel
#
# @JimInhofe @SenatorLankford
# https://t.co/zSkOtnebAi
# Hashtags Used:['Resistance', 'Ukraine', 'Iran']
#
# Tweet 991:
# Username:TgrayAlemey
# Description:#stopTigrayGonocide
# Location:
# Following Count:350
# Follower Count:209
# Total Tweets:11590
# Retweet Count:32
# Tweet Text:#humanitycomesfirst As the world focuses on #Ukraine, we urge #AusGov &amp; UN members to not forget Tigray, a region cut off from the world. Very little aid has entered the region, #AusGov can do more! #TigrayCantWait #AusPol #AusGovActNow @MarisePayne @dfat @scottmorrisonMP
# Hashtags Used:['humanitycomesfirst', 'Ukraine', 'AusGov']
#
# Tweet 992:
# Username:chickzpeaz
# Description:Your average 22 year old. They/them. Love is a dagger.
# No minors. ♠💚
# Location:Playing: Offended by Eminem
# Following Count:1367
# Follower Count:23
# Total Tweets:3806
# Retweet Count:123
# Tweet Text:Dear Word, #Ukraine #Mykolaiv need your help!
# Our local animal shelter needs food and water (because Mykolaiv has been surviving waterlessness since April 12), you can donate here:
# PayPal: anyakir483@gmail.com
# Payeer: P1038706006 https://t.co/KlTZgc4Uun
# Hashtags Used:['Ukraine', 'Mykolaiv']
#
# Tweet 993:
# Username:danoneillwrites
# Description:Politics & Arts Writer and Commentator, Left-of-Centre, Author 'The Arc of History - Politics in the Obama Years 2008-2016' Available on Amazon. MBA
# Location:Dublin
# Following Count:1337
# Follower Count:661
# Total Tweets:26015
# Retweet Count:834
# Tweet Text:This man has been working every single day of war. Every time we felt scared, depressed, disappointed, upset - he would just get up and open his booth and sell fruit and veggies.
# I bow to all people of #Ukraine who never stopped working. Never stopped building and moving forward. https://t.co/EKZ46SA0WU
# Hashtags Used:[]
#
# Tweet 994:
# Username:Xenia16024775
# Description:Be brave like Ukraine! 🤍
# Location:
# Following Count:513
# Follower Count:52
# Total Tweets:17799
# Retweet Count:834
# Tweet Text:This man has been working every single day of war. Every time we felt scared, depressed, disappointed, upset - he would just get up and open his booth and sell fruit and veggies.
# I bow to all people of #Ukraine who never stopped working. Never stopped building and moving forward. https://t.co/EKZ46SA0WU
# Hashtags Used:[]
#
# Tweet 995:
# Username:Patje69268040
# Description:#bitcoin
# Location:
# Following Count:333
# Follower Count:56
# Total Tweets:7943
# Retweet Count:60
# Tweet Text:Good night, and Glory to #Ukraine 🇺🇦✊🏻 https://t.co/q6GyABwkwr
# Hashtags Used:['Ukraine']
#
# Tweet 996:
# Username:nelliegracelw
# Description:Don't be afraid, you are not alone.
#
# "America does not go abroad in search of monsters to destroy..." -John Quincy Adams
# Location:Georgia USA
# Following Count:1185
# Follower Count:387
# Total Tweets:1178
# Retweet Count:661
# Tweet Text:How could this pro-#Ukraine tweet reach 73.9K likes❓
# "#Mariupol residents slaughtered by #Russia-ns while cooking food over open fire in yard of their own apartment building. Pls, DON'T LOOK AWAY".
# When I instead LOOK CLOSER, found victims are pro-Russians wearing white armband! https://t.co/NBfxJvZ3u8
# Hashtags Used:['Ukraine', 'Mariupol', 'Russia']
#
# Tweet 997:
# Username:apnairdrops
# Description:
# Location:
# Following Count:3775
# Follower Count:270
# Total Tweets:9140
# Retweet Count:48
# Tweet Text:GIVEAWAY #67
# Flags #Ukraine #City Part.4
#
# 1.Follow me
# 2.Like+Retweet
# 3.Drop #ETH Wallet Address
#
# 48 hrs
#
# #StandWithUkraine️
# #Khmelnytskyi
# #Kirovohrad
# #Luhansk
#
# #NFTs #NFTdrops  #NFTGiveaway   #OpenSeaNFT #NFTartists #NFTCollection  #Polygon #PolygonNFT https://t.co/lxv4CNFUGZ
# Hashtags Used:['Ukraine', 'City', 'ETH']
#
# Tweet 998:
# Username:heidiypi1
# Description:Environmental/humanitarian enthusiast, Astrologer, passionate about community mental health. focus to leading a heart💓directed life, multidimensional being.
# Location:Australia
# Following Count:1094
# Follower Count:316
# Total Tweets:4240
# Retweet Count:129
# Tweet Text:#Ukraine received a World Bank grant in the amount of 495 million euros. https://t.co/eFTmnt6QRi
# Hashtags Used:['Ukraine']
#
# Tweet 999:
# Username:John407116161
# Description:
# Location:
# Following Count:3240
# Follower Count:2017
# Total Tweets:47007
# Retweet Count:119
# Tweet Text:“If you think that we will stop in #Ukraine, you are deeply mistaken, this is just an intermediate stage” says the main Kremlin’s propagandist, Vladimir Solovyev
#
#  https://t.co/0vIBKADZuu
# Hashtags Used:['Ukraine']
#
# Tweet 1000:
# Username:CommanderE2
# Description:Freedom-loving people are prepared to fight & win against enemies of democracy & peace. Together for Victory. #SlavaUkraine #SlavaUkraini #StandUpForUkraine
# Location:RussianLosses.ua
# Following Count:202
# Follower Count:0
# Total Tweets:509
# Retweet Count:285
# Tweet Text:The Armed Forces of #Ukraine liberated the village of Russkaya Lozovaya in the #Kharkiv region. https://t.co/5bzPPfZBFg
# Hashtags Used:['Ukraine', 'Kharkiv']
# Scraping has completed!

# %%
tweets= pd.read_csv("scraped_tweets.csv")
tweets
# Out:
#      Unnamed: 0         username  \
# 0             0   Mike_Fabricant
# 1             1         Fidget02
# 2             2  WilliamMcTweets
# 3             3       wodenblake
# 4             4       MichelPir2
# ..          ...              ...
# 995         995    nelliegracelw
# 996         996      apnairdrops
# 997         997        heidiypi1
# 998         998    John407116161
# 999         999      CommanderE2
#
#                                            description  \
# 0    Socially liberal MP for #Lichfield. Believes i...
# 1    Digital forensics & aviation expert. Previousl...
# 2    a work in progress, attorney, veteran, privacy...
# 3                              Herrscher of Chaos 🇬🇧🇩🇪
# 4    veux toujours le bonheur de mes enfants et fai...
# ..                                                 ...
# 995  Don't be afraid, you are not alone. \n\n"Ameri...
# 996                                                NaN
# 997  Environmental/humanitarian enthusiast, Astrolo...
# 998                                                NaN
# 999  Freedom-loving people are prepared to fight & ...
#
#                            location  following  followers  totaltweets  \
# 0    Lichfield in Staffordshire, UK       1232      51348        69164
# 1                                UK       2947       2732        54359
# 2                Massachusetts, USA       1212        151         5362
# 3             Laniakea Supercluster         51         23         4170
# 4                               NaN        940        100        18268
# ..                              ...        ...        ...          ...
# 995                     Georgia USA       1185        387         1178
# 996                             NaN       3775        270         9140
# 997                       Australia       1094        316         4240
# 998                             NaN       3240       2017        47007
# 999                RussianLosses.ua        202          0          509
#
#      retweetcount                                               text  \
# 0               0  from the Foreign Minister of #Ukraine 🇺🇦👇 http...
# 1               0  02/05/2022 #StandWithUkraine #Ukraine #Digital...
# 2             402  NEW: Pentagon says #Ukraine forces pushed #Rus...
# 3             539  #American howitzers will arrive in #Ukraine ve...
# 4              61  Goodnight #Ukraine. Just a reminder. https://t...
# ..            ...                                                ...
# 995           661  How could this pro-#Ukraine tweet reach 73.9K ...
# 996            48  GIVEAWAY #67\nFlags #Ukraine #City Part.4\n\n1...
# 997           129  #Ukraine received a World Bank grant in the am...
# 998           119  “If you think that we will stop in #Ukraine, y...
# 999           285  The Armed Forces of #Ukraine liberated the vil...
#
#                                               hashtags
# 0                                          ['Ukraine']
# 1    ['StandWithUkraine', 'Ukraine', 'DigitalResist...
# 2                                ['Ukraine', 'Russia']
# 3                              ['American', 'Ukraine']
# 4                                          ['Ukraine']
# ..                                                 ...
# 995                  ['Ukraine', 'Mariupol', 'Russia']
# 996                         ['Ukraine', 'City', 'ETH']
# 997                                        ['Ukraine']
# 998                                        ['Ukraine']
# 999                             ['Ukraine', 'Kharkiv']
#
# [1000 rows x 10 columns]

# %%
#Select the influencers from the 1000 tweets based on followers on twitter
influencers=tweets.sort_values(by='followers', ascending= False).head(12)
influencers
# Out:
#      Unnamed: 0         username  \
# 576         576    LucioQuincioC
# 442         442    nonprofitorgs
# 107         107         morgfair
# 388         388      tzDiscovery
# 414         414      tzDiscovery
# 436         436  Militarylandnet
# 0             0   Mike_Fabricant
# 619         619       KEigendorf
# 802         802       OzerKhalid
# 237         237    HemingwaysDad
# 708         708         kk131066
# 180         180         kk131066
#
#                                            description  \
# 576  #TeamHDP @Lucioquincio1. " Instagram https://t...
# 442  Promotes nonprofits doing great work in the wo...
# 107  Actress. Foreign policy, politics, science & h...
# 388  Get live Tweets of current issues and share wi...
# 414  Get live Tweets of current issues and share wi...
# 436  Military blog focusing primarily on 🇺🇦 Ukraini...
# 0    Socially liberal MP for #Lichfield. Believes i...
# 619  International Reporter for German TV ZDF / her...
# 802  Psy Ops | Advisor to Heads of State | Statecra...
# 237  Father, Gentleman, published poet, news junky,...
# 708  SAY WHAT YOU MEAN & MEAN WHAT YOU SAY\n\nWARNI...
# 180  SAY WHAT YOU MEAN & MEAN WHAT YOU SAY\n\nWARNI...
#
#                            location  following  followers  totaltweets  \
# 576                        Proud 🇺🇸       1229     860025      1170693
# 442                       Worldwide     366366     776641        32154
# 107                             NaN      15079     160019       791676
# 388                        Tanzania     114950     151642       662810
# 414                        Tanzania     114950     151642       662810
# 436                             NaN         23     143848         2646
# 0    Lichfield in Staffordshire, UK       1232      51348        69164
# 619             Berlin, Deutschland       2471      41292         2510
# 802    Istanbul │London │Islamabad       36881      40776        38450
# 237                  World Wide Web      15812      35807        32742
# 708          Kuala Lumpur, Malaysia      26981      32230       129326
# 180          Kuala Lumpur, Malaysia      26981      32230       129326
#
#      retweetcount                                               text  \
# 576           352  The Prosecutor General's Office of #Ukraine re...
# 442             3  Even before war in #Ukraine, global food secur...
# 107             8  After a bombardment a cat got trapped in a des...
# 388            85  #Ukraine: A destroyed Ukrainian BTR-4E armored...
# 414            66  #Ukraine: Ukrainian forces destroyed a #Russia...
# 436             9  ✍️The 68th day of Russian Invasion - summary o...
# 0               0  from the Foreign Minister of #Ukraine 🇺🇦👇 http...
# 619           310  The 23-year-old nurse from Lysychansk (Luhansk...
# 802          1202  My thoughts on some potential #Neocon objectiv...
# 237            23  10 #Russian generals have died in #Ukraine, am...
# 708             1  https://t.co/tWiXm5nNNc\n\n1997\n#Biden warned...
# 180             0  https://t.co/bZINaze1Cw\n\nBBC: #Biden has mad...
#
#                                               hashtags
# 576                                        ['Ukraine']
# 442                                        ['Ukraine']
# 107                                      ['Ukrainian']
# 388                            ['Ukraine', 'Mariupol']
# 414                              ['Ukraine', 'Russia']
# 436  ['Ukraine', 'UkraineInvasion', 'UkraineRussiaW...
# 0                                          ['Ukraine']
# 619                                                 []
# 802  ['Neocon', 'Zelenskyy', 'Putin', 'Ukraine', 'D...
# 237                             ['Russian', 'Ukraine']
# 708  ['Biden', 'Russian', 'NATO', 'UkraineRussiaWar...
# 180  ['Biden', 'Russia', 'Ukraine', 'UkraineRussiaW...
